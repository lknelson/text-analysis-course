# %% [markdown]
# ## Additional Exercises for 02.27: Dictionary Method

# %% [markdown]
# Ex.
#
# 1. Read in the `childrens_lit.csv.bz2` file from the `data` folder.
# 2. Come up with a hypothesis on what you think the sentiment ratings is for children's literature.
# 3. Do a sentiment analysis on a subset of chilren's literature using the dictionary method from lecture.
#     - Use the positive and negative words from lecture

# %% [markdown]
# ### Question 1

# %%
import pandas as pd
import nltk
import string
import matplotlib.pyplot as plt


#read in our data
df = pd.read_csv("../data/childrens_lit.csv.bz2", sep = '\t', encoding = 'utf-8', compression = 'bz2', index_col=0)
df = df.dropna(subset=["text"])
df
# Out:
#                                                  title author gender  year  \
# 0                                A Dog with a Bad Name          Male  1886
# 1                                    A Final Reckoning          Male  1887
# 2        A House Party, Don Gesualdo, and A Rainy June        Female  1887
# 3                                  A Houseful of Girls        Female  1889
# 4                                A Little Country Girl        Female  1885
# 5                                        A Round Dozen        Female  1883
# 6                                      A Sailor's Lass        Female  1886
# 7                                     A World of Girls        Female  1886
# 8                                   Adrift in the Wild          Male  1887
# 9                                 Adventures in Africa          Male  1883
# 10                             Adventures in Australia          Male  1885
# 11                                          All Adrift          Male  1882
# 12                                Battles With the Sea          Male  1883
# 13                         Bimbi: Stories for Children        Female  1882
# 14          Blown To Bits; Or The Lonely Man of Rakata          Male  1889
# 15                  Blue Lights Hot Work In the Soudan          Male  1888
# 16                               Bonnie Prince Charlie          Male  1888
# 17                                       Breaking Away          Male  1887
# 18                                    Brownsmith's Boy          Male  1886
# 19                                         Bunyip Land          Male  1880
# 20                                      By Sheer Pluck          Male  1884
# 21                               Captain Bayley's Heir          Male  1889
# 22                                              Clover        Female  1888
# 23                                   Crown and Sceptre          Male  1889
# 24                                    Dick o' the Fens          Male  1885
# 25                                          Down South          Male  1880
# 26   Dusty Diamonds Cut and Polished: A Tale of  Ci...          Male  1884
# 27                                Elsie's Kith and Kin        Female  1886
# 28                               Elsie's New Relations        Female  1883
# 29                                        Facing Death          Male  1882
# ..                                                 ...           ...   ...
# 102                            The Master of the Shell          Male  1887
# 103                            The Middy and the Moors          Male  1888
# 104                                 The New Forest Spy          Male  1885
# 105                               The Palace Beautiful        Female  1887
# 106                                  The Prairie Chief          Male  1886
# 107                            The Princess and Curdie          Male  1883
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
# 109                                  The Silver Canyon          Male  1884
# 110                                 The Story of Patsy        Female  1883
# 111                               The Thorogood Family          Male  1883
# 112                                   The Twin Cousins        Female  1880
# 113                                     The Two Elsies        Female  1885
# 114                            The Willoughby Captains          Male  1883
# 115                                  The Young Buglers          Male  1880
# 116                             The Young Carthaginian          Male  1887
# 117                                The Young Colonists          Male  1885
# 118                                  The Young Trawler          Male  1884
# 119                                         Three Boys          Male  1889
# 120                          Through Forest and Stream          Male  1884
# 121                                   Through the Fray          Male  1886
# 122                                    Treasure Island          Male  1883
# 123                                       Twice Bought          Male  1885
# 124                                         Two Arrows          Male  1886
# 125                 Uncle Remus: His Songs and Sayings          Male  1880
# 126                                 Under Drake's Flag          Male  1883
# 127                                       Up the River          Male  1881
# 116  THE YOUNG CARTHAGINIAN  A STORY OF THE TIMES O...
# 117  The Young Colonists A Story of the Zulu and Bo...
# 118  The Project Gutenberg EBook of The Young Trawl...
# 119  Three Boys; or The Chiefs of the Clan Mackhai,...
# 120  THROUGH FOREST AND STREAM; OR, THE QUEST OF TH...
# 121  THROUGH THE FRAY  A TALE OF THE LUDDITE RIOTS ...
# 122  TREASURE ISLAND  by Robert Louis Stevenson    ...
# 123  The Project Gutenberg EBook of Twice Bought, b...
# 124  TWO ARROWS      HARPER'S YOUNG PEOPLE'S SERIES...
# 125  Uncle Remus: His Songs and His Sayings  By Joe...
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 127  UP THE RIVER  OR  YACHTING ON THE MISSISSIPPI ...
# 128  WHAT KATY DID NEXT  BY  SUSAN COOLIDGE    This...
# 129                   WINNING HIS SPURS            ...
# 130  WITH CLIVE IN INDIA:  Or, The Beginnings of an...
# 131  \n WITH WOLFE IN CANADA  Or The Winning of a C...
#
# [127 rows x 4 columns]

# %% [markdown]
# Since the number of children literaturs is a lot to analyze, we'll just randomly select 5 books to do a sentiment analysis using the dictionary method.
#
# *Note*: In case you're not familiar with seed. Seed is just a function that initializes a fixed state for random number generatoring. Basically if everyone uses the same number as an input to `seed()`, then everyone will get the same result when generating randomly.

# %%
import numpy as np
np.random.seed(1)
df = df.sample(5)
df
# Out:
#                                                  title author gender  year  \
# 126                                 Under Drake's Flag          Male  1883
# 47                                           Kidnapped          Male  1886
# 75                                  The Bee-Man of Orn          Male  1887
# 95                                    The Island Queen          Male  1885
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
#
#                                                   text
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 47   KIDNAPPED      BEING      MEMOIRS OF THE ADVEN...
# 75   FRANK R. STOCKTON'S WRITINGS.         *       ...
# 95   The Project Gutenberg EBook of The Island Quee...
# 108  The Project Gutenberg EBook of The Red Man's R...

# %% [markdown]
# ### Question 2

# %% [markdown]
# Since these literatures are written for children, the overall sentiment rating is probably positive.

# %% [markdown]
# ### Question 3

# %%
# Your code here
df['text_lc'] = df['text'].str.lower()
df['text_split'] = df['text_lc'].apply(nltk.word_tokenize)
df['text_split_clean'] = df['text_split'].apply(lambda x : [word for word in x if word not in string.punctuation])
df
# Out:
#                                                  title author gender  year  \
# 126                                 Under Drake's Flag          Male  1883
# 47                                           Kidnapped          Male  1886
# 75                                  The Bee-Man of Orn          Male  1887
# 95                                    The Island Queen          Male  1885
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
#
#                                                   text  \
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 47   KIDNAPPED      BEING      MEMOIRS OF THE ADVEN...
# 75   FRANK R. STOCKTON'S WRITINGS.         *       ...
# 95   The Project Gutenberg EBook of The Island Quee...
# 108  The Project Gutenberg EBook of The Red Man's R...
#
#                                                text_lc  \
# 126  under drake's flag:  a tale of the spanish mai...
# 47   kidnapped      being      memoirs of the adven...
# 75   frank r. stockton's writings.         *       ...
# 95   the project gutenberg ebook of the island quee...
# 108  the project gutenberg ebook of the red man's r...
#
#                                             text_split  \
# 126  [under, drake, 's, flag, :, a, tale, of, the, ...
# 47   [kidnapped, being, memoirs, of, the, adventure...
# 75   [frank, r., stockton, 's, writings, ., *, *, *...
# 95   [the, project, gutenberg, ebook, of, the, isla...
# 108  [the, project, gutenberg, ebook, of, the, red,...
#
#                                       text_split_clean
# 126  [under, drake, 's, flag, a, tale, of, the, spa...
# 47   [kidnapped, being, memoirs, of, the, adventure...
# 75   [frank, r., stockton, 's, writings, new, unifo...
# 95   [the, project, gutenberg, ebook, of, the, isla...
# 108  [the, project, gutenberg, ebook, of, the, red,...

# %%
df['text_length'] = df['text_split_clean'].apply(len)
df
# Out:
#                                                  title author gender  year  \
# 126                                 Under Drake's Flag          Male  1883
# 47                                           Kidnapped          Male  1886
# 75                                  The Bee-Man of Orn          Male  1887
# 95                                    The Island Queen          Male  1885
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
#
#                                                   text  \
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 47   KIDNAPPED      BEING      MEMOIRS OF THE ADVEN...
# 75   FRANK R. STOCKTON'S WRITINGS.         *       ...
# 95   The Project Gutenberg EBook of The Island Quee...
# 108  The Project Gutenberg EBook of The Red Man's R...
#
#                                                text_lc  \
# 126  under drake's flag:  a tale of the spanish mai...
# 47   kidnapped      being      memoirs of the adven...
# 75   frank r. stockton's writings.         *       ...
# 95   the project gutenberg ebook of the island quee...
# 108  the project gutenberg ebook of the red man's r...
#
#                                             text_split  \
# 126  [under, drake, 's, flag, :, a, tale, of, the, ...
# 47   [kidnapped, being, memoirs, of, the, adventure...
# 75   [frank, r., stockton, 's, writings, ., *, *, *...
# 95   [the, project, gutenberg, ebook, of, the, isla...
# 108  [the, project, gutenberg, ebook, of, the, red,...
#
#                                       text_split_clean  text_length
# 126  [under, drake, 's, flag, a, tale, of, the, spa...       110331
# 47   [kidnapped, being, memoirs, of, the, adventure...        86353
# 75   [frank, r., stockton, 's, writings, new, unifo...        57839
# 95   [the, project, gutenberg, ebook, of, the, isla...        63870
# 108  [the, project, gutenberg, ebook, of, the, red,...        77672

# %%
# Your code here
pos_sent = open("../data/positive_words.txt", encoding='utf-8').read()
neg_sent = open("../data/negative_words.txt", encoding='utf-8').read()
positive_words = pos_sent.split('\n')
negative_words = neg_sent.split('\n')

# %%
df['num_pos_words'] = df['text_split_clean'].apply(lambda x: len([word for word in x if word in positive_words]))
df['num_neg_words'] = df['text_split_clean'].apply(lambda x: len([word for word in x if word in negative_words]))
df
# Out:
#                                                  title author gender  year  \
# 126                                 Under Drake's Flag          Male  1883
# 47                                           Kidnapped          Male  1886
# 75                                  The Bee-Man of Orn          Male  1887
# 95                                    The Island Queen          Male  1885
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
#
#                                                   text  \
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 47   KIDNAPPED      BEING      MEMOIRS OF THE ADVEN...
# 75   FRANK R. STOCKTON'S WRITINGS.         *       ...
# 95   The Project Gutenberg EBook of The Island Quee...
# 108  The Project Gutenberg EBook of The Red Man's R...
#
#                                                text_lc  \
# 126  under drake's flag:  a tale of the spanish mai...
# 47   kidnapped      being      memoirs of the adven...
# 75   frank r. stockton's writings.         *       ...
# 95   the project gutenberg ebook of the island quee...
# 108  the project gutenberg ebook of the red man's r...
#
#                                             text_split  \
# 126  [under, drake, 's, flag, :, a, tale, of, the, ...
# 47   [kidnapped, being, memoirs, of, the, adventure...
# 75   [frank, r., stockton, 's, writings, ., *, *, *...
# 95   [the, project, gutenberg, ebook, of, the, isla...
# 108  [the, project, gutenberg, ebook, of, the, red,...
#
#                                       text_split_clean  text_length  \
# 126  [under, drake, 's, flag, a, tale, of, the, spa...       110331
# 47   [kidnapped, being, memoirs, of, the, adventure...        86353
# 75   [frank, r., stockton, 's, writings, new, unifo...        57839
# 95   [the, project, gutenberg, ebook, of, the, isla...        63870
# 108  [the, project, gutenberg, ebook, of, the, red,...        77672
#
#      num_pos_words  num_neg_words  prop_pos_words  prop_neg_words
# 126           4363           3531        0.039545        0.032004
# 47            3047           2770        0.035285        0.032078
# 75            2325           1321        0.040198        0.022839
# 95            2556           2247        0.040019        0.035181
# 108           2905           2642        0.037401        0.034015

# %%
df['prop_pos_words'] = df['num_pos_words']/df['text_length']
df['prop_neg_words'] = df['num_neg_words']/df['text_length']
df
# Out:
#                                                  title author gender  year  \
# 126                                 Under Drake's Flag          Male  1883
# 47                                           Kidnapped          Male  1886
# 75                                  The Bee-Man of Orn          Male  1887
# 95                                    The Island Queen          Male  1885
# 108  The Red Man's Revenge A Tale of the Red River ...          Male  1880
#
#                                                   text  \
# 126  Under Drake's Flag:  A Tale of the Spanish Mai...
# 47   KIDNAPPED      BEING      MEMOIRS OF THE ADVEN...
# 75   FRANK R. STOCKTON'S WRITINGS.         *       ...
# 95   The Project Gutenberg EBook of The Island Quee...
# 108  The Project Gutenberg EBook of The Red Man's R...
#
#                                                text_lc  \
# 126  under drake's flag:  a tale of the spanish mai...
# 47   kidnapped      being      memoirs of the adven...
# 75   frank r. stockton's writings.         *       ...
# 95   the project gutenberg ebook of the island quee...
# 108  the project gutenberg ebook of the red man's r...
#
#                                             text_split  \
# 126  [under, drake, 's, flag, :, a, tale, of, the, ...
# 47   [kidnapped, being, memoirs, of, the, adventure...
# 75   [frank, r., stockton, 's, writings, ., *, *, *...
# 95   [the, project, gutenberg, ebook, of, the, isla...
# 108  [the, project, gutenberg, ebook, of, the, red,...
#
#                                       text_split_clean  text_length  \
# 126  [under, drake, 's, flag, a, tale, of, the, spa...       110331
# 47   [kidnapped, being, memoirs, of, the, adventure...        86353
# 75   [frank, r., stockton, 's, writings, new, unifo...        57839
# 95   [the, project, gutenberg, ebook, of, the, isla...        63870
# 108  [the, project, gutenberg, ebook, of, the, red,...        77672
#
#      num_pos_words  num_neg_words  prop_pos_words  prop_neg_words
# 126           4363           3531        0.039545        0.032004
# 47            3047           2770        0.035285        0.032078
# 75            2325           1321        0.040198        0.022839
# 95            2556           2247        0.040019        0.035181
# 108           2905           2642        0.037401        0.034015
