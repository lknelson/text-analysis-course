# %% [markdown]
# # Using Weighted Dictionaries
#
# On Monday we applied dictionaries that consisted of lists of words associated with a category. We worked through the example of counting positive emotion words and negative emotion words in our music reviews dataset. This served as a rudimentary sentiment analysis tool.
#
# In the reading today the authors use lists of phrases that were associated with categories, in their case Democrats and Republicans, but they did not simply indicate whether a phrase was associated with a category, but *how strongly* it was associated with a category. In other words, their dictionary was a list of weighted words.
#
# Today we'll use a weighted dictionary to compare the relative average concreteness of the words used in Austen's *Pride and Prejudice* versus Alcott's *A Garland for Girls*.
#
# This could be done using a regular dictionary: a list of concrete and abstract words. Instead, we'll use a crowdsourced dictionary that provides an average "concreteness score" for a large number of English words.
#
# ### Outline
#
# 1. Weighted dictionary
# 2. Merging a DTM with a weighted dictionary
#     * Term-Document Matrix (transposed DTM)
#     * Merging dataframes
# 3. Weight the term frequencies by their concreteness score
# 3. Calculating an average concreteness score for each text
#
# ### 1. Read a concreteness score dictionary
#
# First we'll create a pandas dataframe from the concreteness score dictionary, saved on our hard drive in the form of a .csv file.
#
# This dictionary comes from work by [Marc Brysbaert, Amy Beth Warriner, and Victor Kuperman.](https://link.springer.com/article/10.3758/s13428-013-0403-5) In summary:
#
# The authors obtained Concreteness ratings for 37,058 English words and 2,896 two-word expressions (such as zebra crossing and zoom in), by means of a norming study using Internet crowdsourcing for data collection. They had over 4,000 participants rate 5 words on a concreteness scale, from 1 (very abstract) to 5 (very concrete). They define concrete words as words you can experience through the senses, and abstract words as words that you cannot experience through the senses. They provide the average concreteness score and the standard deviation for each word.
#
# Let's read in the data.

# %%
import pandas
from sklearn.feature_extraction.text import CountVectorizer

con_score = pandas.read_csv('../data/Concreteness_ratings_Brysbaert_et_al.csv')
con_score
# Out:
#                Word  Bigram  Conc.M  Conc.SD  Unknown  Total  Percent_known  \
# 0                 a       0    1.46     1.14        2     30           0.93
# 1        a cappella       1    2.92     1.44        3     29           0.90
# 2          aardvark       0    4.68     0.86        0     28           1.00
# 3             aback       0    1.65     1.07        4     27           0.85
# 4            abacus       0    4.52     1.12        2     29           0.93
# 5           abandon       0    2.54     1.45        1     27           0.96
# 6         abandoned       0    2.52     1.27        0     29           1.00
# 7         abandonee       0    2.92     1.28        4     28           0.86
# 8         abandoner       0    2.50     1.50        2     30           0.93
# 9       abandonment       0    2.54     1.29        0     28           1.00
# 10        abasement       0    1.67     1.01        2     26           0.92
# 11        abatement       0    1.92     1.29        4     30           0.87
# 12       abbreviate       0    2.59     1.53        0     27           1.00
# 13      abbreviated       0    3.10     1.54        0     30           1.00
# 14     abbreviation       0    3.07     1.51        0     29           1.00
# 15         abdicate       0    2.08     1.29        2     28           0.93
# 16          abdomen       0    4.70     0.67        0     27           1.00
# 17        abdominal       0    4.28     1.16        0     29           1.00
# 18      abdominally       0    3.15     1.46        3     30           0.90
# 19           abduct       0    2.88     1.51        2     28           0.93
# 20         abductee       0    3.27     1.44        0     30           1.00
# 21        abduction       0    3.07     1.47        0     27           1.00
# 22         abductor       0    3.89     1.37        0     28           1.00
# 23            abhor       0    1.81     1.17        3     29           0.90
# 24       abhorrence       0    2.15     1.26        1     28           0.96
# 25      abhorrently       0    2.04     1.32        2     29           0.93
# 26        abhorring       0    1.68     0.80        4     29           0.86
# 27            abide       0    1.68     0.86        0     28           1.00
# 28          abiding       0    2.07     1.13        0     29           1.00
# 29        abidingly       0    1.82     0.94        2     30           0.93
# ...             ...     ...     ...      ...      ...    ...            ...
# 39924     zinfandel       0    4.23     1.15        4     26           0.85
# 39925          zing       0    1.23     0.43        4     26           0.85
# 39926        zinger       0    2.20     1.22        3     28           0.89
# 39927           zip       0    3.50     1.45        1     29           0.97
# 39928      ZIP code       1    3.77     1.59        0     30           1.00
# 39929       zipfile       0    4.00     1.28        1     29           0.97
# 39930        zipper       0    4.83     0.54        0     29           1.00
# 39931      zippered       0    4.12     1.09        2     27           0.93
# 39932       zipping       0    3.38     1.60        0     26           1.00
# 39933         zippy       0    2.39     1.42        0     28           1.00
# 39934          zips       0    3.67     1.17        1     25           0.96
# 39935     zirconium       0    4.27     1.19        3     29           0.90
# 39936           zit       0    4.85     0.60        1     28           0.96
# 39937        zodiac       0    3.07     1.78        0     28           1.00
# 39938      zodiacal       0    2.17     1.50        4     27           0.85
# 39939        zombie       0    4.16     1.14        1     26           0.96
# 39940          zone       0    3.07     1.58        0     29           1.00
# 39941         zoned       0    2.77     1.45        0     26           1.00
# 39942        zoning       0    2.45     1.53        0     29           1.00
# 39943           zoo       0    4.81     0.40        0     27           1.00
# 39944     zookeeper       0    4.71     0.53        0     28           1.00
# 39945    zoological       0    2.40     1.40        0     30           1.00
# 39946  zoologically       0    2.33     1.43        0     24           1.00
# 39947     zoologist       0    4.30     1.02        0     30           1.00
# 39948       zoology       0    3.37     1.55        0     27           1.00
# 39949          zoom       0    3.10     1.49        0     30           1.00
# 39950       zoom in       1    3.57     1.40        0     28           1.00
# 39951     zoom lens       1    4.81     0.49        1     27           0.96
# 39952     zoophobia       0    2.04     1.02        2     25           0.92
# 39953      zucchini       0    4.87     0.57        0     30           1.00
#
#        SUBTLEX    Dom_Pos
# 0      1041179    Article
# 1            0    Err:512
# 2           21       Noun
# 3           15     Adverb
# 4           12       Noun
# 5          413       Verb
# 6          678       Verb
# 7            0    Err:512
# 8            1       Noun
# 9           49       Noun
# 10           0    Err:512
# 11           3       Noun
# 12           1       Verb
# 13          16  Adjective
# 14          12       Noun
# 15           9       Verb
# 16         171       Noun
# 17         174  Adjective
# 18           0    Err:512
# 19          36       Verb
# 20          20    Err:512
# 21         185       Noun
# 22          18       Noun
# 23          12       Verb
# 24           0    Err:512
# 25           0    Err:512
# 26           0    Err:512
# 27         138       Verb
# 28          25  Adjective
# 29           0    Err:512
# ...        ...        ...
# 39924        3       Noun
# 39925       60       Verb
# 39926       11       Noun
# 39927      389       Verb
# 39928        0    Err:512
# 39929        0    Err:512
# 39930      144       Noun
# 39931        3       Verb
# 39932       22       Verb
# 39933       19  Adjective
# 39934       17       Verb
# 39935        2       Noun
# 39936       52       Noun
# 39937       31       Noun
# 39938        2  Adjective
# 39939      184       Noun
# 39940     1026       Noun
# 39941       18       Verb
# 39942       61       Noun
# 39943      696       Noun
# 39944        1       Noun
# 39945        8  Adjective
# 39946        0    Err:512
# 39947       12       Noun
# 39948       17       Noun
# 39949      181       Verb
# 39950        0    Err:512
# 39951        0    Err:512
# 39952        0    Err:512
# 39953       49       Noun
#
# [39954 rows x 9 columns]

# %% [markdown]
# We can see the most concrete and most abstract words by sorting on 'Conc.M'.

# %%
con_score[['Word','Conc.M']].sort_values(by='Conc.M',ascending=False)
# Out:
#                      Word  Conc.M
# 2547                  bat    5.00
# 10689               eagle    5.00
# 30740               shawl    5.00
# 36046            umbrella    5.00
# 2526               basket    5.00
# 22561         nail polish    5.00
# 22562       nail scissors    5.00
# 22563           nailbrush    5.00
# 30604      sewing machine    5.00
# 22701                neck    5.00
# 22714           nectarine    5.00
# 22888  newspaper clipping    5.00
# 36016               udder    5.00
# 16881            ice cube    5.00
# 16880           ice cream    5.00
# 22948          nightshirt    5.00
# 2499         baseball bat    5.00
# 2478            barracuda    5.00
# 5798                clock    5.00
# 39161              whisky    5.00
# 34133          tablespoon    5.00
# 11588           escalator    5.00
# 1234             antelope    5.00
# 11596            escargot    5.00
# 2431           barbedwire    5.00
# 15005              gravel    5.00
# 5525       cigarette butt    5.00
# 30161          sea turtle    5.00
# 2552           bath towel    5.00
# 2677            bed sheet    5.00
# ...                   ...     ...
# 18678           intuitive    1.23
# 18856        irresolutely    1.22
# 2668              because    1.22
# 17958          infinitely    1.22
# 12799        figuratively    1.21
# 16927          idealistic    1.21
# 17347        in principle    1.21
# 18548      interpretively    1.21
# 992            ambivalent    1.21
# 34623            terribly    1.21
# 18679         intuitively    1.21
# 36779            unenvied    1.21
# 17893        inexplicable    1.21
# 667          agnostically    1.20
# 34839              though    1.20
# 17413            inasmuch    1.20
# 11352        enlightening    1.19
# 16971                  if    1.19
# 16931            idealize    1.19
# 2779               belief    1.19
# 25112             perhaps    1.19
# 7075      conventionalism    1.18
# 6520      conceptualistic    1.18
# 39087          whatsoever    1.17
# 32381         spiritually    1.14
# 39703               would    1.12
# 32378        spirituality    1.07
# 941              although    1.07
# 10905                  eh    1.04
# 11618       essentialness    1.04
#
# [39954 rows x 2 columns]

# %%
con_score[['Word','Conc.M']].sort_values(by='Conc.M',ascending=True)
# Out:
#                   Word  Conc.M
# 10905               eh    1.04
# 11618    essentialness    1.04
# 32378     spirituality    1.07
# 941           although    1.07
# 39703            would    1.12
# 32381      spiritually    1.14
# 39087       whatsoever    1.17
# 6520   conceptualistic    1.18
# 7075   conventionalism    1.18
# 16971               if    1.19
# 16931         idealize    1.19
# 25112          perhaps    1.19
# 2779            belief    1.19
# 11352     enlightening    1.19
# 34839           though    1.20
# 667       agnostically    1.20
# 17413         inasmuch    1.20
# 18679      intuitively    1.21
# 34623         terribly    1.21
# 992         ambivalent    1.21
# 36779         unenvied    1.21
# 17893     inexplicable    1.21
# 18548   interpretively    1.21
# 17347     in principle    1.21
# 12799     figuratively    1.21
# 16927       idealistic    1.21
# 17958       infinitely    1.22
# 18856     irresolutely    1.22
# 2668           because    1.22
# 39114         wherever    1.23
# ...                ...     ...
# 23494              oat    5.00
# 8851         deodorant    5.00
# 22948       nightshirt    5.00
# 25015          penguin    5.00
# 5448        chopsticks    5.00
# 25020            penis    5.00
# 25051        pepperoni    5.00
# 26044        porcupine    5.00
# 5525    cigarette butt    5.00
# 26023          popcorn    5.00
# 25902       polar bear    5.00
# 5798             clock    5.00
# 25851       pocketbook    5.00
# 39563         woodpile    5.00
# 25670            plank    5.00
# 25636        place mat    5.00
# 39161           whisky    5.00
# 25630            pizza    5.00
# 25606        pitchfork    5.00
# 25603          pitbull    5.00
# 5998        coffee cup    5.00
# 6000    coffee machine    5.00
# 25521           pillow    5.00
# 25483              pig    5.00
# 38679           walrus    5.00
# 25452    pick-up truck    5.00
# 6160              comb    5.00
# 6476    computer mouse    5.00
# 7132            cookie    5.00
# 37017         unicycle    5.00
#
# [39954 rows x 2 columns]

# %% [markdown]
# ### 2. Merging a DTM with a weighted dictionary
#
# The goal is to merge this score with our document term matrix, so we can calculate the average concreteness score for our texts.
#
# To do this, we'll first create the DTM from our two novels, transpose this matrix, and merge it with the dataframe created above. We'll merge on the column 'Word'.
#
# First, create the DTM.

# %%
text_list = []
#open and read the novels, save them as variables
austen_string = open('../data/Austen_PrideAndPrejudice.txt', encoding='utf-8').read()
alcott_string = open('../data/Alcott_GarlandForGirls.txt', encoding='utf-8').read()

#append each novel to the list
text_list.append(austen_string)
text_list.append(alcott_string)

countvec = CountVectorizer(stop_words="english")

novels_df = pandas.DataFrame(countvec.fit_transform(text_list).toarray(), columns=countvec.get_feature_names())
novels_df
# Out:
#    000  1500  15th  1813  1887  18th  20  2001  26th  30 ...   york  young  \
# 0    0     0     1     2     0     1   0     0     1   0 ...      1    129
# 1    1     1     1     0     2     0   1     1     0   1 ...      2    109
#
#    younge  younger  youngest  youngsters  youth  youthful  youths  zip
# 0       4       29        14           0      9         0       1    0
# 1       0        7         2           1      9         1       3    1
#
# [2 rows x 9901 columns]

# %% [markdown]
# Like monday, we'll next take a subset of the DTM, keeping only the intersection between the words in our corpus and the word in the dictionary.

# %%
columns=list(novels_df)
columns_con = [word for word in columns if word in list(con_score['Word'])]
columns_con[:10]
# Out:
# ['aback',
#  'abatement',
#  'abhorrence',
#  'abide',
#  'abiding',
#  'able',
#  'aboard',
#  'abode',
#  'abominable',
#  'abominably']

# %%
novels_df_con = novels_df[columns_con]
novels_df_con
# Out:
#    aback  abatement  abhorrence  abide  abiding  able  aboard  abode  \
# 0      0          1           6      1        1    54       0      8
# 1      1          0           0      2        0    26       2      0
#
#    abominable  abominably ...   yes  yesterday  yield  yielding  yonder  \
# 0           6           4 ...    76         13      4         3       0
# 1           0           0 ...    30          1      0         0       1
#
#    young  younger  youth  youthful  zip
# 0    129       29      9         0    0
# 1    109        7      9         1    1
#
# [2 rows x 6226 columns]

# %% [markdown]
# Next, transpose the matrix, rename the column, and merge with the dictionary dataframe.

# %%
df = novels_df_con.transpose()
df
# Out:
#                 0    1
# aback           0    1
# abatement       1    0
# abhorrence      6    0
# abide           1    2
# abiding         1    0
# able           54   26
# aboard          0    2
# abode           8    0
# abominable      6    0
# abominably      4    0
# abominate       2    0
# abound          1    0
# abroad          4    3
# abrupt          1    1
# abruptly        2    1
# abruptness      2    0
# absence        27    1
# absent          4    2
# absolute        4    0
# absolutely     18    1
# absorbed        0    7
# absorbing       0    1
# absurd          5    2
# absurdity       1    0
# abundance       0    1
# abundant        1    0
# abundantly      3    0
# abuse           2    0
# abusive         2    0
# accent          4    0
# ...           ...  ...
# wretchedly      1    0
# wretchedness    2    0
# wring           0    2
# wrinkled        0    1
# write          39   13
# writer          3    1
# writing        14   11
# written        19   10
# wrong          15    7
# wrote          21    6
# wrought         0    1
# wrung           0    2
# yachting        0    1
# yard            0    2
# yarn            0    2
# yawn            2    4
# yawning         1    0
# year           29   24
# yearning        0    2
# yellow          0   16
# yes            76   30
# yesterday      13    1
# yield           4    0
# yielding        3    0
# yonder          0    1
# young         129  109
# younger        29    7
# youth           9    9
# youthful        0    1
# zip             0    1
#
# [6226 rows x 2 columns]

# %%
df.rename(columns={0: 'Austen', 1: 'Alcott'}, inplace=True)
df
# Out:
#               Austen  Alcott
# aback              0       1
# abatement          1       0
# abhorrence         6       0
# abide              1       2
# abiding            1       0
# able              54      26
# aboard             0       2
# abode              8       0
# abominable         6       0
# abominably         4       0
# abominate          2       0
# abound             1       0
# abroad             4       3
# abrupt             1       1
# abruptly           2       1
# abruptness         2       0
# absence           27       1
# absent             4       2
# absolute           4       0
# absolutely        18       1
# absorbed           0       7
# absorbing          0       1
# absurd             5       2
# absurdity          1       0
# abundance          0       1
# abundant           1       0
# abundantly         3       0
# abuse              2       0
# abusive            2       0
# accent             4       0
# ...              ...     ...
# wretchedly         1       0
# wretchedness       2       0
# wring              0       2
# wrinkled           0       1
# write             39      13
# writer             3       1
# writing           14      11
# written           19      10
# wrong             15       7
# wrote             21       6
# wrought            0       1
# wrung              0       2
# yachting           0       1
# yard               0       2
# yarn               0       2
# yawn               2       4
# yawning            1       0
# year              29      24
# yearning           0       2
# yellow             0      16
# yes               76      30
# yesterday         13       1
# yield              4       0
# yielding           3       0
# yonder             0       1
# young            129     109
# younger           29       7
# youth              9       9
# youthful           0       1
# zip                0       1
#
# [6226 rows x 2 columns]

# %%
#Rename the index 'Word', and reset the index, so the words become a column in our dataframe and we get a new index.
df.index.names = ['Word']
df.reset_index(inplace=True)

df
# Out:
#               Word  Austen  Alcott
# 0            aback       0       1
# 1        abatement       1       0
# 2       abhorrence       6       0
# 3            abide       1       2
# 4          abiding       1       0
# 5             able      54      26
# 6           aboard       0       2
# 7            abode       8       0
# 8       abominable       6       0
# 9       abominably       4       0
# 10       abominate       2       0
# 11          abound       1       0
# 12          abroad       4       3
# 13          abrupt       1       1
# 14        abruptly       2       1
# 15      abruptness       2       0
# 16         absence      27       1
# 17          absent       4       2
# 18        absolute       4       0
# 19      absolutely      18       1
# 20        absorbed       0       7
# 21       absorbing       0       1
# 22          absurd       5       2
# 23       absurdity       1       0
# 24       abundance       0       1
# 25        abundant       1       0
# 26      abundantly       3       0
# 27           abuse       2       0
# 28         abusive       2       0
# 29          accent       4       0
# ...            ...     ...     ...
# 6196    wretchedly       1       0
# 6197  wretchedness       2       0
# 6198         wring       0       2
# 6199      wrinkled       0       1
# 6200         write      39      13
# 6201        writer       3       1
# 6202       writing      14      11
# 6203       written      19      10
# 6204         wrong      15       7
# 6205         wrote      21       6
# 6206       wrought       0       1
# 6207         wrung       0       2
# 6208      yachting       0       1
# 6209          yard       0       2
# 6210          yarn       0       2
# 6211          yawn       2       4
# 6212       yawning       1       0
# 6213          year      29      24
# 6214      yearning       0       2
# 6215        yellow       0      16
# 6216           yes      76      30
# 6217     yesterday      13       1
# 6218         yield       4       0
# 6219      yielding       3       0
# 6220        yonder       0       1
# 6221         young     129     109
# 6222       younger      29       7
# 6223         youth       9       9
# 6224      youthful       0       1
# 6225           zip       0       1
#
# [6226 rows x 3 columns]

# %%
#merge with our dictionary dataframe, called 'con_score'
df = df.merge(con_score, on = 'Word')
df
# Out:
#               Word  Austen  Alcott  Bigram  Conc.M  Conc.SD  Unknown  Total  \
# 0            aback       0       1       0    1.65     1.07        4     27
# 1        abatement       1       0       0    1.92     1.29        4     30
# 2       abhorrence       6       0       0    2.15     1.26        1     28
# 3            abide       1       2       0    1.68     0.86        0     28
# 4          abiding       1       0       0    2.07     1.13        0     29
# 5             able      54      26       0    2.38     1.42        1     27
# 6           aboard       0       2       0    3.97     1.30        0     30
# 7            abode       8       0       0    3.92     1.38        2     26
# 8       abominable       6       0       0    1.89     0.99        2     30
# 9       abominably       4       0       0    2.14     1.13        1     30
# 10       abominate       2       0       0    1.68     0.99        3     28
# 11          abound       1       0       0    2.27     1.19        2     28
# 12          abroad       4       3       0    2.72     1.43        1     26
# 13          abrupt       1       1       0    2.27     1.11        0     30
# 14        abruptly       2       1       0    2.36     1.28        0     28
# 15      abruptness       2       0       0    2.04     1.02        0     27
# 16         absence      27       1       0    2.31     1.35        0     26
# 17          absent       4       2       0    2.70     1.44        0     30
# 18        absolute       4       0       0    1.81     1.24        0     27
# 19      absolutely      18       1       0    1.97     1.19        0     30
# 20        absorbed       0       7       0    2.44     1.26        0     25
# 21       absorbing       0       1       0    3.33     1.00        0     27
# 22          absurd       5       2       0    1.64     0.95        0     28
# 23       absurdity       1       0       0    1.25     0.59        1     29
# 24       abundance       0       1       0    2.21     1.20        1     29
# 25        abundant       1       0       0    2.83     1.46        0     30
# 26      abundantly       3       0       0    2.22     1.28        0     27
# 27           abuse       2       0       0    2.71     1.27        0     28
# 28         abusive       2       0       0    2.55     1.43        0     29
# 29          accent       4       0       0    3.26     1.16        0     27
# ...            ...     ...     ...     ...     ...      ...      ...    ...
# 6196    wretchedly       1       0       0    1.70     0.82        1     28
# 6197  wretchedness       2       0       0    2.07     1.10        0     29
# 6198         wring       0       2       0    4.00     1.24        3     30
# 6199      wrinkled       0       1       0    4.29     1.16        0     31
# 6200         write      39      13       0    4.22     1.09        0     27
# 6201        writer       3       1       0    4.32     0.98        0     28
# 6202       writing      14      11       0    3.70     1.49        0     27
# 6203       written      19      10       0    4.04     1.04        0     28
# 6204         wrong      15       7       0    1.83     1.10        0     29
# 6205         wrote      21       6       0    3.55     1.12        0     29
# 6206       wrought       0       1       0    2.42     1.44        0     24
# 6207         wrung       0       2       0    3.30     1.14        2     29
# 6208      yachting       0       1       0    4.04     1.22        2     29
# 6209          yard       0       2       0    4.82     0.48        0     28
# 6210          yarn       0       2       0    4.93     0.37        1     30
# 6211          yawn       2       4       0    4.46     0.84        0     28
# 6212       yawning       1       0       0    4.15     1.32        1     27
# 6213          year      29      24       0    3.25     1.32        0     28
# 6214      yearning       0       2       0    2.00     1.12        0     28
# 6215        yellow       0      16       0    4.30     1.06        0     30
# 6216           yes      76      30       0    2.14     1.27        0     29
# 6217     yesterday      13       1       0    3.00     1.73        0     29
# 6218         yield       4       0       0    2.93     1.51        0     29
# 6219      yielding       3       0       0    2.82     1.22        0     28
# 6220        yonder       0       1       0    2.59     1.34        1     28
# 6221         young     129     109       0    3.16     1.46        0     25
# 6222       younger      29       7       0    2.79     1.45        0     28
# 6223         youth       9       9       0    3.28     1.34        0     25
# 6224      youthful       0       1       0    2.90     1.26        0     29
# 6225           zip       0       1       0    3.50     1.45        1     29
#
#       Percent_known  SUBTLEX       Dom_Pos
# 0              0.85       15        Adverb
# 1              0.87        3          Noun
# 2              0.96        0       Err:512
# 3              1.00      138          Verb
# 4              1.00       25     Adjective
# 5              0.96     8155     Adjective
# 6              1.00     1358        Adverb
# 7              0.92       33          Noun
# 8              0.93       32     Adjective
# 9              0.97        8        Adverb
# 10             0.89        3          Verb
# 11             0.93       18          Verb
# 12             0.96      250        Adverb
# 13             1.00       58     Adjective
# 14             1.00       45        Adverb
# 15             1.00        4          Noun
# 16             1.00      322          Noun
# 17             1.00      131     Adjective
# 18             1.00      577     Adjective
# 19             1.00     5769        Adverb
# 20             1.00       78          Verb
# 21             1.00       23          Verb
# 22             1.00      495     Adjective
# 23             0.97       32          Noun
# 24             0.97       45          Noun
# 25             1.00       29     Adjective
# 26             1.00       21        Adverb
# 27             1.00      523          Noun
# 28             1.00       83     Adjective
# 29             1.00      621          Noun
# ...             ...      ...           ...
# 6196           0.96        2        Adverb
# 6197           1.00        2          Noun
# 6198           0.90       62          Verb
# 6199           1.00       86     Adjective
# 6200           1.00     6467          Verb
# 6201           1.00     1200          Noun
# 6202           1.00     2852          Verb
# 6203           1.00     2247          Verb
# 6204           1.00    26678     Adjective
# 6205           1.00     3629          Verb
# 6206           1.00       44          Verb
# 6207           0.93       14          Verb
# 6208           0.93       17          Noun
# 6209           1.00     1278          Noun
# 6210           0.97       81          Noun
# 6211           1.00       51          Verb
# 6212           0.96       48          Verb
# 6213           1.00    14174          Noun
# 6214           1.00       81          Verb
# 6215           1.00     1724     Adjective
# 6216           1.00   101835  Interjection
# 6217           1.00     4935        Adverb
# 6218           1.00      206          Verb
# 6219           1.00       22          Verb
# 6220           0.96      178        Adverb
# 6221           1.00    12402     Adjective
# 6222           1.00     1257     Adjective
# 6223           1.00      858          Noun
# 6224           1.00       79     Adjective
# 6225           0.97      389          Verb
#
# [6226 rows x 11 columns]

# %% [markdown]
# ### 3. Weighting the term frequencies by the concreteness score
#
# Now we can weight the term frquency cells by the concreteness score, by multiplying the frequency count column by the concreteness score column.

# %%
df['austen_con_score'] = df['Austen'] * df['Conc.M']
df
# Out:
#               Word  Austen  Alcott  Bigram  Conc.M  Conc.SD  Unknown  Total  \
# 0            aback       0       1       0    1.65     1.07        4     27
# 1        abatement       1       0       0    1.92     1.29        4     30
# 2       abhorrence       6       0       0    2.15     1.26        1     28
# 3            abide       1       2       0    1.68     0.86        0     28
# 4          abiding       1       0       0    2.07     1.13        0     29
# 5             able      54      26       0    2.38     1.42        1     27
# 6           aboard       0       2       0    3.97     1.30        0     30
# 7            abode       8       0       0    3.92     1.38        2     26
# 8       abominable       6       0       0    1.89     0.99        2     30
# 9       abominably       4       0       0    2.14     1.13        1     30
# 10       abominate       2       0       0    1.68     0.99        3     28
# 11          abound       1       0       0    2.27     1.19        2     28
# 12          abroad       4       3       0    2.72     1.43        1     26
# 13          abrupt       1       1       0    2.27     1.11        0     30
# 14        abruptly       2       1       0    2.36     1.28        0     28
# 15      abruptness       2       0       0    2.04     1.02        0     27
# 16         absence      27       1       0    2.31     1.35        0     26
# 17          absent       4       2       0    2.70     1.44        0     30
# 18        absolute       4       0       0    1.81     1.24        0     27
# 19      absolutely      18       1       0    1.97     1.19        0     30
# 20        absorbed       0       7       0    2.44     1.26        0     25
# 21       absorbing       0       1       0    3.33     1.00        0     27
# 22          absurd       5       2       0    1.64     0.95        0     28
# 23       absurdity       1       0       0    1.25     0.59        1     29
# 24       abundance       0       1       0    2.21     1.20        1     29
# 25        abundant       1       0       0    2.83     1.46        0     30
# 26      abundantly       3       0       0    2.22     1.28        0     27
# 27           abuse       2       0       0    2.71     1.27        0     28
# 28         abusive       2       0       0    2.55     1.43        0     29
# 29          accent       4       0       0    3.26     1.16        0     27
# ...            ...     ...     ...     ...     ...      ...      ...    ...
# 6196    wretchedly       1       0       0    1.70     0.82        1     28
# 6197  wretchedness       2       0       0    2.07     1.10        0     29
# 6198         wring       0       2       0    4.00     1.24        3     30
# 6199      wrinkled       0       1       0    4.29     1.16        0     31
# 6200         write      39      13       0    4.22     1.09        0     27
# 6201        writer       3       1       0    4.32     0.98        0     28
# 6202       writing      14      11       0    3.70     1.49        0     27
# 6203       written      19      10       0    4.04     1.04        0     28
# 6204         wrong      15       7       0    1.83     1.10        0     29
# 6205         wrote      21       6       0    3.55     1.12        0     29
# 6206       wrought       0       1       0    2.42     1.44        0     24
# 6207         wrung       0       2       0    3.30     1.14        2     29
# 6208      yachting       0       1       0    4.04     1.22        2     29
# 6209          yard       0       2       0    4.82     0.48        0     28
# 6210          yarn       0       2       0    4.93     0.37        1     30
# 6211          yawn       2       4       0    4.46     0.84        0     28
# 6212       yawning       1       0       0    4.15     1.32        1     27
# 6213          year      29      24       0    3.25     1.32        0     28
# 6214      yearning       0       2       0    2.00     1.12        0     28
# 6215        yellow       0      16       0    4.30     1.06        0     30
# 6216           yes      76      30       0    2.14     1.27        0     29
# 6217     yesterday      13       1       0    3.00     1.73        0     29
# 6218         yield       4       0       0    2.93     1.51        0     29
# 6219      yielding       3       0       0    2.82     1.22        0     28
# 6220        yonder       0       1       0    2.59     1.34        1     28
# 6221         young     129     109       0    3.16     1.46        0     25
# 6222       younger      29       7       0    2.79     1.45        0     28
# 6223         youth       9       9       0    3.28     1.34        0     25
# 6224      youthful       0       1       0    2.90     1.26        0     29
# 6225           zip       0       1       0    3.50     1.45        1     29
#
#       Percent_known  SUBTLEX       Dom_Pos  austen_con_score
# 0              0.85       15        Adverb              0.00
# 1              0.87        3          Noun              1.92
# 2              0.96        0       Err:512             12.90
# 3              1.00      138          Verb              1.68
# 4              1.00       25     Adjective              2.07
# 5              0.96     8155     Adjective            128.52
# 6              1.00     1358        Adverb              0.00
# 7              0.92       33          Noun             31.36
# 8              0.93       32     Adjective             11.34
# 9              0.97        8        Adverb              8.56
# 10             0.89        3          Verb              3.36
# 11             0.93       18          Verb              2.27
# 12             0.96      250        Adverb             10.88
# 13             1.00       58     Adjective              2.27
# 14             1.00       45        Adverb              4.72
# 15             1.00        4          Noun              4.08
# 16             1.00      322          Noun             62.37
# 17             1.00      131     Adjective             10.80
# 18             1.00      577     Adjective              7.24
# 19             1.00     5769        Adverb             35.46
# 20             1.00       78          Verb              0.00
# 21             1.00       23          Verb              0.00
# 22             1.00      495     Adjective              8.20
# 23             0.97       32          Noun              1.25
# 24             0.97       45          Noun              0.00
# 25             1.00       29     Adjective              2.83
# 26             1.00       21        Adverb              6.66
# 27             1.00      523          Noun              5.42
# 28             1.00       83     Adjective              5.10
# 29             1.00      621          Noun             13.04
# ...             ...      ...           ...               ...
# 6196           0.96        2        Adverb              1.70
# 6197           1.00        2          Noun              4.14
# 6198           0.90       62          Verb              0.00
# 6199           1.00       86     Adjective              0.00
# 6200           1.00     6467          Verb            164.58
# 6201           1.00     1200          Noun             12.96
# 6202           1.00     2852          Verb             51.80
# 6203           1.00     2247          Verb             76.76
# 6204           1.00    26678     Adjective             27.45
# 6205           1.00     3629          Verb             74.55
# 6206           1.00       44          Verb              0.00
# 6207           0.93       14          Verb              0.00
# 6208           0.93       17          Noun              0.00
# 6209           1.00     1278          Noun              0.00
# 6210           0.97       81          Noun              0.00
# 6211           1.00       51          Verb              8.92
# 6212           0.96       48          Verb              4.15
# 6213           1.00    14174          Noun             94.25
# 6214           1.00       81          Verb              0.00
# 6215           1.00     1724     Adjective              0.00
# 6216           1.00   101835  Interjection            162.64
# 6217           1.00     4935        Adverb             39.00
# 6218           1.00      206          Verb             11.72
# 6219           1.00       22          Verb              8.46
# 6220           0.96      178        Adverb              0.00
# 6221           1.00    12402     Adjective            407.64
# 6222           1.00     1257     Adjective             80.91
# 6223           1.00      858          Noun             29.52
# 6224           1.00       79     Adjective              0.00
# 6225           0.97      389          Verb              0.00
#
# [6226 rows x 12 columns]

# %%
df['alcott_con_score'] = df['Alcott'] * df['Conc.M']
df
# Out:
#               Word  Austen  Alcott  Bigram  Conc.M  Conc.SD  Unknown  Total  \
# 0            aback       0       1       0    1.65     1.07        4     27
# 1        abatement       1       0       0    1.92     1.29        4     30
# 2       abhorrence       6       0       0    2.15     1.26        1     28
# 3            abide       1       2       0    1.68     0.86        0     28
# 4          abiding       1       0       0    2.07     1.13        0     29
# 5             able      54      26       0    2.38     1.42        1     27
# 6           aboard       0       2       0    3.97     1.30        0     30
# 7            abode       8       0       0    3.92     1.38        2     26
# 8       abominable       6       0       0    1.89     0.99        2     30
# 9       abominably       4       0       0    2.14     1.13        1     30
# 10       abominate       2       0       0    1.68     0.99        3     28
# 11          abound       1       0       0    2.27     1.19        2     28
# 12          abroad       4       3       0    2.72     1.43        1     26
# 13          abrupt       1       1       0    2.27     1.11        0     30
# 14        abruptly       2       1       0    2.36     1.28        0     28
# 15      abruptness       2       0       0    2.04     1.02        0     27
# 16         absence      27       1       0    2.31     1.35        0     26
# 17          absent       4       2       0    2.70     1.44        0     30
# 18        absolute       4       0       0    1.81     1.24        0     27
# 19      absolutely      18       1       0    1.97     1.19        0     30
# 20        absorbed       0       7       0    2.44     1.26        0     25
# 21       absorbing       0       1       0    3.33     1.00        0     27
# 22          absurd       5       2       0    1.64     0.95        0     28
# 23       absurdity       1       0       0    1.25     0.59        1     29
# 24       abundance       0       1       0    2.21     1.20        1     29
# 25        abundant       1       0       0    2.83     1.46        0     30
# 26      abundantly       3       0       0    2.22     1.28        0     27
# 27           abuse       2       0       0    2.71     1.27        0     28
# 28         abusive       2       0       0    2.55     1.43        0     29
# 29          accent       4       0       0    3.26     1.16        0     27
# ...            ...     ...     ...     ...     ...      ...      ...    ...
# 6196    wretchedly       1       0       0    1.70     0.82        1     28
# 6197  wretchedness       2       0       0    2.07     1.10        0     29
# 6198         wring       0       2       0    4.00     1.24        3     30
# 6199      wrinkled       0       1       0    4.29     1.16        0     31
# 6200         write      39      13       0    4.22     1.09        0     27
# 6201        writer       3       1       0    4.32     0.98        0     28
# 6202       writing      14      11       0    3.70     1.49        0     27
# 6203       written      19      10       0    4.04     1.04        0     28
# 6204         wrong      15       7       0    1.83     1.10        0     29
# 6205         wrote      21       6       0    3.55     1.12        0     29
# 6206       wrought       0       1       0    2.42     1.44        0     24
# 6207         wrung       0       2       0    3.30     1.14        2     29
# 6208      yachting       0       1       0    4.04     1.22        2     29
# 6209          yard       0       2       0    4.82     0.48        0     28
# 6210          yarn       0       2       0    4.93     0.37        1     30
# 6211          yawn       2       4       0    4.46     0.84        0     28
# 6212       yawning       1       0       0    4.15     1.32        1     27
# 6213          year      29      24       0    3.25     1.32        0     28
# 6214      yearning       0       2       0    2.00     1.12        0     28
# 6215        yellow       0      16       0    4.30     1.06        0     30
# 6216           yes      76      30       0    2.14     1.27        0     29
# 6217     yesterday      13       1       0    3.00     1.73        0     29
# 6218         yield       4       0       0    2.93     1.51        0     29
# 6219      yielding       3       0       0    2.82     1.22        0     28
# 6220        yonder       0       1       0    2.59     1.34        1     28
# 6221         young     129     109       0    3.16     1.46        0     25
# 6222       younger      29       7       0    2.79     1.45        0     28
# 6223         youth       9       9       0    3.28     1.34        0     25
# 6224      youthful       0       1       0    2.90     1.26        0     29
# 6225           zip       0       1       0    3.50     1.45        1     29
#
#       Percent_known  SUBTLEX       Dom_Pos  austen_con_score  alcott_con_score
# 0              0.85       15        Adverb              0.00              1.65
# 1              0.87        3          Noun              1.92              0.00
# 2              0.96        0       Err:512             12.90              0.00
# 3              1.00      138          Verb              1.68              3.36
# 4              1.00       25     Adjective              2.07              0.00
# 5              0.96     8155     Adjective            128.52             61.88
# 6              1.00     1358        Adverb              0.00              7.94
# 7              0.92       33          Noun             31.36              0.00
# 8              0.93       32     Adjective             11.34              0.00
# 9              0.97        8        Adverb              8.56              0.00
# 10             0.89        3          Verb              3.36              0.00
# 11             0.93       18          Verb              2.27              0.00
# 12             0.96      250        Adverb             10.88              8.16
# 13             1.00       58     Adjective              2.27              2.27
# 14             1.00       45        Adverb              4.72              2.36
# 15             1.00        4          Noun              4.08              0.00
# 16             1.00      322          Noun             62.37              2.31
# 17             1.00      131     Adjective             10.80              5.40
# 18             1.00      577     Adjective              7.24              0.00
# 19             1.00     5769        Adverb             35.46              1.97
# 20             1.00       78          Verb              0.00             17.08
# 21             1.00       23          Verb              0.00              3.33
# 22             1.00      495     Adjective              8.20              3.28
# 23             0.97       32          Noun              1.25              0.00
# 24             0.97       45          Noun              0.00              2.21
# 25             1.00       29     Adjective              2.83              0.00
# 26             1.00       21        Adverb              6.66              0.00
# 27             1.00      523          Noun              5.42              0.00
# 28             1.00       83     Adjective              5.10              0.00
# 29             1.00      621          Noun             13.04              0.00
# ...             ...      ...           ...               ...               ...
# 6196           0.96        2        Adverb              1.70              0.00
# 6197           1.00        2          Noun              4.14              0.00
# 6198           0.90       62          Verb              0.00              8.00
# 6199           1.00       86     Adjective              0.00              4.29
# 6200           1.00     6467          Verb            164.58             54.86
# 6201           1.00     1200          Noun             12.96              4.32
# 6202           1.00     2852          Verb             51.80             40.70
# 6203           1.00     2247          Verb             76.76             40.40
# 6204           1.00    26678     Adjective             27.45             12.81
# 6205           1.00     3629          Verb             74.55             21.30
# 6206           1.00       44          Verb              0.00              2.42
# 6207           0.93       14          Verb              0.00              6.60
# 6208           0.93       17          Noun              0.00              4.04
# 6209           1.00     1278          Noun              0.00              9.64
# 6210           0.97       81          Noun              0.00              9.86
# 6211           1.00       51          Verb              8.92             17.84
# 6212           0.96       48          Verb              4.15              0.00
# 6213           1.00    14174          Noun             94.25             78.00
# 6214           1.00       81          Verb              0.00              4.00
# 6215           1.00     1724     Adjective              0.00             68.80
# 6216           1.00   101835  Interjection            162.64             64.20
# 6217           1.00     4935        Adverb             39.00              3.00
# 6218           1.00      206          Verb             11.72              0.00
# 6219           1.00       22          Verb              8.46              0.00
# 6220           0.96      178        Adverb              0.00              2.59
# 6221           1.00    12402     Adjective            407.64            344.44
# 6222           1.00     1257     Adjective             80.91             19.53
# 6223           1.00      858          Noun             29.52             29.52
# 6224           1.00       79     Adjective              0.00              2.90
# 6225           0.97      389          Verb              0.00              3.50
#
# [6226 rows x 13 columns]

# %% [markdown]
# ### 3. Calculating the Average Concreteness Score
#
# Exercise: Calculate and print the average concreteness score for each text. Careful! Think through this before you implement it. You want the average score, normalized over all the words in the text.

# %%
#code here
#we'll devide the sum of the concreteness score by the total word count for each novel
print("Mean Concreteness for Austen's 'Pride and Prejudice'")
print(df['austen_con_score'].sum()/df['Austen'].sum())
print()
print("Mean Concreteness for Alcott's 'A Garland for Girls'")
print(df['alcott_con_score'].sum()/df['Alcott'].sum())
# Out:
# Mean Concreteness for Austen's 'Pride and Prejudice'
# 2.78328905828
#
# Mean Concreteness for Alcott's 'A Garland for Girls'
# 3.1534507874

# %% [markdown]
# ### 4. Assessing the difference
#
# So there is a difference, but what does it mean? What is the magnitude of the difference?
#
# We can look at the difference between the two means as a percent difference based on the scale range. We can calculate this using simple math.

# %%
#first find the difference between the means by substracting one from the other
3.1534507874-2.78328905828
# Out:
# 0.37016172912000034

# %%
#Find the range of concreteness scores
print(df['Conc.M'].min())
print(df['Conc.M'].max())
# Out:
# 1.17
# 5.0

# %%
#The scale range
df['Conc.M'].max() - df['Conc.M'].min()
# Out:
# 3.8300000000000001

# %%
#Calculate the difference of means as a percent of this range
(0.37/3.83)* 100
# Out:
# 9.660574412532636

# %% [markdown]
# Ex: Print the most concrete and abstract terms in Austen and in Alcott.
# HINT: You can't simply sort on the column 'austen_con_score' and so on. Why not? What are your next steps?

# %%
#Create a new dataframe that keeps only words that have a non-zero value in Alcott
df_alcott = df[df['Alcott']>0]
#Sort on 'Conc.M' and pring in descending order for most concrete words
df_alcott[['Word', 'Conc.M', 'Alcott']].sort_values(by=['Conc.M', 'Alcott'], ascending = False)
# Out:
#                Word  Conc.M  Alcott
# 2692          house    5.00      65
# 6033          water    5.00      32
# 470             bed    5.00      25
# 590           boots    5.00      17
# 2139           fish    5.00      17
# 438          basket    5.00      16
# 400            baby    5.00      10
# 3577           neck    5.00       9
# 413            ball    5.00       8
# 921           clock    5.00       8
# 1283            cup    5.00       8
# 1738            ear    5.00       8
# 2179         flower    5.00       8
# 2531   handkerchief    5.00       8
# 3075           knee    5.00       8
# 5646           tree    5.00       8
# 1646           doll    5.00       7
# 525            bird    5.00       5
# 2099           fern    5.00       5
# 3956         pillow    5.00       5
# 262           apple    5.00       4
# 2128         finger    5.00       4
# 4308       railroad    5.00       4
# 5572           tire    5.00       4
# 1305          daisy    5.00       3
# 4708           sand    5.00       3
# 4887          shawl    5.00       3
# 5198         stairs    5.00       3
# 5517        thimble    5.00       3
# 5558          tiger    5.00       3
# ...             ...     ...     ...
# 144             ago    1.42      17
# 3397         merely    1.42       3
# 3120         lately    1.41       3
# 1031        concept    1.41       2
# 5684       trusting    1.40       2
# 2892      injustice    1.40       1
# 3154         legacy    1.40       1
# 1911      evidently    1.38      13
# 2413       goodness    1.38       2
# 4813         seldom    1.38       2
# 1434       deserved    1.38       1
# 5385        suppose    1.37      12
# 77         actually    1.37       5
# 557           bliss    1.37       1
# 3002   irreverently    1.36       1
# 3574    necessarily    1.36       1
# 2226        forever    1.34       6
# 3264           luck    1.33       8
# 380           avail    1.33       1
# 1454        despite    1.33       1
# 4053    possibility    1.33       1
# 2062        fateful    1.31       1
# 3494         morals    1.31       1
# 5816         unjust    1.31       1
# 6083      whichever    1.30       1
# 1891     especially    1.28      12
# 5094       somewhat    1.28       5
# 4705  sanctimonious    1.28       1
# 2671           hope    1.25      40
# 6080     whatsoever    1.17       1
#
# [4262 rows x 3 columns]

# %%
#Create a new dataframe that keeps only words that have a non-zero value in Austen
df_austen = df[df['Austen']>0]
df_austen[['Word', 'Conc.M', 'Austen']].sort_values(by=['Conc.M', 'Austen'], ascending = False)
# Out:
#                   Word  Conc.M  Austen
# 2692             house    5.00     108
# 413               ball    5.00      36
# 5198            stairs    5.00      24
# 470                bed    5.00       6
# 921              clock    5.00       6
# 2139              fish    5.00       5
# 2681             horse    5.00       4
# 6033             water    5.00       4
# 2457            gravel    5.00       3
# 862            chimney    5.00       1
# 1283               cup    5.00       1
# 1738               ear    5.00       1
# 2531      handkerchief    5.00       1
# 3074             kitty    4.97      71
# 5358              suit    4.97       7
# 943               coat    4.97       4
# 4309              rain    4.97       4
# 650             bridge    4.97       3
# 2522              hair    4.97       3
# 2399             glove    4.97       1
# 3072           kitchen    4.97       1
# 4910              shoe    4.97       1
# 5543            throat    4.97       1
# 493               bell    4.96       6
# 2342              gate    4.96       6
# 292                arm    4.96       4
# 3021             jewel    4.96       1
# 5478             teeth    4.96       1
# 5499              tent    4.96       1
# 2639              hill    4.93      10
# ...                ...     ...     ...
# 375          austerity    1.38       1
# 2817     inconceivable    1.38       1
# 4120        pressingly    1.38       1
# 4147        principles    1.38       1
# 5385           suppose    1.37      48
# 77            actually    1.37      12
# 4973         sincerely    1.37       9
# 3003       irrevocably    1.37       1
# 4239         prudently    1.37       1
# 3574       necessarily    1.36       4
# 4829          sensibly    1.36       2
# 2831        indefinite    1.36       1
# 3493          moralize    1.36       1
# 1530      disbelieving    1.34       1
# 4053       possibility    1.33      13
# 3264              luck    1.33       4
# 2816  incomprehensible    1.33       2
# 380              avail    1.33       1
# 3373        mediocrity    1.33       1
# 5816            unjust    1.31       4
# 971        comfortless    1.31       1
# 6083         whichever    1.30       2
# 1891        especially    1.28      22
# 5094          somewhat    1.28       8
# 5715        ultimately    1.26       1
# 2671              hope    1.25     121
# 23           absurdity    1.25       1
# 109     advantageously    1.24       2
# 2873        infinitely    1.22       4
# 490             belief    1.19      15
#
# [4070 rows x 3 columns]
